# %% [markdown]
# <a href="https://colab.research.google.com/github/xing-wang-kai/PANDAS_PREFICIFICACAO_IMOVEIS/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRECIFICAÇÃO INTELIGENTE DE IMóVEIS
#
# ### OBJETIVO
#
# A precificação inteligente para hospedagem é uma estratégia de estimação de preços de forma automatizada e dinâmica, que considera fatores como oferta e demanda, sazonalidade, eventos locais, características do local, entre outros. Com base nessas informações, um algoritmo pode ajustar os preços para maximizar a receita e a rentabilidade da pessoa proprietária.
#
# Normalmente essa estratégia é aplicada a um modelo de inteligência artificial que ajusta automaticamente os preços das diárias. Por exemplo, se a demanda por hospedagem em um determinado destino aumentar, a precificação inteligente ajustará automaticamente os preços das diárias para cima, com o fim de maximizar a receita da propriedade. Da mesma forma, se a demanda diminuir, a precificação inteligente ajustará os preços para baixo para manter a ocupação da propriedade e evitar perdas financeiras.
#
# Embora o machine learning seja frequentemente usado em sistemas de precificação inteligente, existem outras abordagens que podem ser usadas para implementar esses sistemas. Por exemplo, pode-se usar um modelo de regras baseado em lógica e heurísticas para definir as condições e regras de precificação.
#
# Mesmo assim, é importante ressaltar que o uso de machine learning pode oferecer benefícios adicionais, como a capacidade de analisar grandes volumes de dados, identificar padrões de comportamento do consumidor e ajustar os preços de forma mais precisa e dinâmica.

# %% [markdown]
# #### PANDAS
# importar no projeto a biblioteca pandas

# %%
import pandas as pd

# %% [markdown]
# #### Váriaveis para arquivos JSON MOVEIS DISPONIVEIS E DADOS HORSPEDAGENS

# %%
link_moveis_disponiveis = "https://caelum-online-public.s3.amazonaws.com/2928-transformacao-manipulacao-dados/moveis_disponiveis.json"
link_dados_hospedagens = "https://caelum-online-public.s3.amazonaws.com/2928-transformacao-manipulacao-dados/dados_hospedagem.json"

# %% [markdown]
# # CRIAR DATAFRAMES
#
# Criar os dataframes com as funções Read_Json
#
# dataframe 1 = moveis disponiveis
# dataframe 2 = dados hospedagens

# %%
moveis_disponiveis = pd.read_json(link_moveis_disponiveis)
moveis_disponiveis
# Out:
#           id        data  vaga_disponivel    preco
# 0        857  2016-01-04            False     None
# 1        857  2016-01-05            False     None
# 2        857  2016-01-06            False     None
# 3        857  2016-01-07            False     None
# 4        857  2016-01-08            False     None
# ...      ...         ...              ...      ...
# 364995  3279  2016-12-29             True  $140.00
# 364996  3279  2016-12-30             True  $140.00
# 364997  3279  2016-12-31             True  $140.00
# 364998  3279  2017-01-01             True  $140.00
# 364999  3279  2017-01-02            False     None
#
# [365000 rows x 4 columns]

# %% [markdown]
# ## NORMALIZAR JSON
#
# na base de dados para hospedaens os dados estão alinhados dentro de dictionarios, para corrigir o alinahmento padrões e conseguir ver os dados com maiores detalhes e importante sempre usar a função json normaliza do pandas retornando assim os dados mais importantes

# %%
dados_hospedagens = pd.read_json(link_dados_hospedagens)

dados_hospedagens = pd.json_normalize(dados_hospedagens["info_moveis"])

dados_hospedagens
# Out:
#    avaliacao_geral experiencia_local max_hospedes  \
# 0             10.0                --            1
# 1             10.0                --           10
# 2             10.0                --           11
# 3             10.0                --           12
# 4             10.0                --           14
# ..             ...               ...          ...
# 65             nan                --            5
# 66             nan                --            6
# 67             nan                --            7
# 68             nan                --            8
# 69             nan                --            9
#
#                                       descricao_local  \
# 0   [This clean and comfortable one bedroom sits r...
# 1   [Welcome to the heart of the 'Ballard Brewery ...
# 2   [New modern house built in 2013.  Spectacular ...
# 3   [Our NW style home is 3200+ sq ft with 3 level...
# 4   [Perfect for groups. 2 bedrooms, full bathroom...
# ...

# %% [markdown]
# # DADOS NúMERICOS
#
# Como trabalhar com dados numericos para analise e limpesza de dados

# %% [markdown]
# ## Entender os dados
#
# * __avaliacao_geral:__ refere-se à média de notas dadas para a avaliação da hospedagem no imóvel.
#
# * __experiencia_local:__ descreve as experiências oferecidas durante a hospedagem no imóvel.
# * __max_hospedes:__ informa a quantidade máxima de hóspedes que o local permite.
# * __descricao_local:__ descreve o imóvel.
# * __descricao_vizinhanca:__ descreve a vizinhança ao redor do imóvel.
# * __quantidade_banheiros:__ informa a quantidade de banheiros disponíveis.
# * __quantidade_quartos:__ informa a quantidade de quartos disponíveis.
# * __quantidade_camas:__ informa a quantidade de camas disponíveis.
# * __modelo_cama:__ informa o modelo de cama oferecido.
# * __comodidades:__ informa as comodidades oferecidas pelo imóvel.
# * __taxa_deposito:__ informa a taxa de depósito mínima para segurança de hospedagem.
# * __taxa_limpeza:__ informa a taxa cobrada para o serviço de limpeza.
# * __preco:__ refere-se ao preço base a ser cobrado pela diária no imóvel.

# %%
colunas_dados_hospedagem = list(dados_hospedagens.columns)
colunas_dados_hospedagem
# Out:
# ['avaliacao_geral',
#  'experiencia_local',
#  'max_hospedes',
#  'descricao_local',
#  'descricao_vizinhanca',
#  'quantidade_banheiros',
#  'quantidade_quartos',
#  'quantidade_camas',
#  'modelo_cama',
#  'comodidades',
#  'taxa_deposito',
#  'taxa_limpeza',
#  'preco']

# %% [markdown]
# ## Build Function Explode
#
# Para desagrupas os dados das colunas alinhadas em list no Json precisamos usar o metodos Explode passando uma list com o nomes das columns que terão os dados desagrupados.

# %%
dados_hospedagens = dados_hospedagens.explode(colunas_dados_hospedagem[3:])
dados_hospedagens.reset_index(inplace=True, drop=True)
dados_hospedagens.head()
# Out:
#   avaliacao_geral experiencia_local max_hospedes  \
# 0            10.0                --            1
# 1            10.0                --            1
# 2            10.0                --            1
# 3            10.0                --            1
# 4            10.0                --            1
#
#                                      descricao_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 1  Our century old Upper Queen Anne house is loca...
# 2  Cozy room in two-bedroom apartment along the l...
# 3  Very lovely and cozy room for one. Convenientl...
# 4  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descricao_vizinhanca quantidade_banheiros  \
# 0  Lower Queen Anne is near the Seattle Center (s...                    1
# 1  Upper Queen Anne is a really pleasant, unique ...                    1
# 2  The convenience of being in Seattle but on the...                    1
# ...

# %%
dados_hospedagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   avaliacao_geral       3818 non-null   object
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   object
#  3   descricao_local       3818 non-null   object
#  4   descricao_vizinhanca  3818 non-null   object
#  5   quantidade_banheiros  3818 non-null   object
#  6   quantidade_quartos    3818 non-null   object
#  7   quantidade_camas      3818 non-null   object
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  taxa_deposito         3818 non-null   object
#  11  taxa_limpeza          3818 non-null   object
#  12  preco                 3818 non-null   object
# dtypes: object(13)
# memory usage: 387.9+ KB

# %%
import numpy as np

# %%
dados_hospedagens["max_hospedes"] = dados_hospedagens["max_hospedes"].astype(np.int64)

# %%
dados_hospedagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   avaliacao_geral       3818 non-null   object
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descricao_local       3818 non-null   object
#  4   descricao_vizinhanca  3818 non-null   object
#  5   quantidade_banheiros  3818 non-null   object
#  6   quantidade_quartos    3818 non-null   object
#  7   quantidade_camas      3818 non-null   object
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  taxa_deposito         3818 non-null   object
#  11  taxa_limpeza          3818 non-null   object
#  12  preco                 3818 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 387.9+ KB

# %%
cols_numeric = ['quantidade_banheiros', 'quantidade_quartos', 'quantidade_camas' ]

# %%
dados_hospedagens[cols_numeric]  = dados_hospedagens[cols_numeric].astype(np.int64)
dados_hospedagens['avaliacao_geral'] = dados_hospedagens['avaliacao_geral'].astype(np.float64)
dados_hospedagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   avaliacao_geral       3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descricao_local       3818 non-null   object
#  4   descricao_vizinhanca  3818 non-null   object
#  5   quantidade_banheiros  3818 non-null   int64
#  6   quantidade_quartos    3818 non-null   int64
#  7   quantidade_camas      3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  taxa_deposito         3818 non-null   object
#  11  taxa_limpeza          3818 non-null   object
#  12  preco                 3818 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 387.9+ KB

# %%
cols_float = ['taxa_deposito', 'taxa_limpeza', 'preco']

dados_hospedagens[cols_float] = dados_hospedagens[cols_float].replace("[\$^?://A-Za-z]", "", regex=True).replace("\,", "", regex=True).astype(np.float64)
dados_hospedagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   avaliacao_geral       3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descricao_local       3818 non-null   object
#  4   descricao_vizinhanca  3818 non-null   object
#  5   quantidade_banheiros  3818 non-null   int64
#  6   quantidade_quartos    3818 non-null   int64
#  7   quantidade_camas      3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  taxa_deposito         3818 non-null   float64
#  11  taxa_limpeza          3818 non-null   float64
#  12  preco                 3818 non-null   float64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 387.9+ KB

# %%
dados_hospedagens.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 1  Our century old Upper Queen Anne house is loca...
# 2  Cozy room in two-bedroom apartment along the l...
# 3  Very lovely and cozy room for one. Convenientl...
# 4  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  Lower Queen Anne is near the Seattle Center (s...                     1
# 1  Upper Queen Anne is a really pleasant, unique ...                     1
# 2  The convenience of being in Seattle but on the...                     1
# ...

# %% [markdown]
# ## DADOS DE TEXTO
#
# Como manipular e tratar dados de textos em DATAFRAMES

# %%
cols_text_dados_hospedagens = ['descricao_local', 'descricao_vizinhanca']

dados_hospedagens[cols_text_dados_hospedagens] = dados_hospedagens[cols_text_dados_hospedagens].applymap( lambda x: x.lower())

dados_hospedagens.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  this clean and comfortable one bedroom sits ri...
# 1  our century old upper queen anne house is loca...
# 2  cozy room in two-bedroom apartment along the l...
# 3  very lovely and cozy room for one. convenientl...
# 4  the “studio at mibbett hollow' is in a beautif...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  lower queen anne is near the seattle center (s...                     1
# 1  upper queen anne is a really pleasant, unique ...                     1
# 2  the convenience of being in seattle but on the...                     1
# ...

# %%
dados_hospedagens['descricao_local'] = dados_hospedagens['descricao_local'].str.replace("[^A-Za-z1-9\-\'[]]", "", regex=True)
dados_hospedagens['descricao_vizinhanca'] = dados_hospedagens['descricao_vizinhanca'].str.replace("[^A-Za-z1-9\-\'[]]", " ", regex=True)
dados_hospedagens.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  this clean and comfortable one bedroom sits ri...
# 1  our century old upper queen anne house is loca...
# 2  cozy room in two-bedroom apartment along the l...
# 3  very lovely and cozy room for one. convenientl...
# 4  the “studio at mibbett hollow' is in a beautif...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  lower queen anne is near the seattle center (s...                     1
# 1  upper queen anne is a really pleasant, unique ...                     1
# 2  the convenience of being in seattle but on the...                     1
# ...

# %%
dados_hospedagens[cols_text_dados_hospedagens] = dados_hospedagens[cols_text_dados_hospedagens].applymap( lambda x: x.split())
dados_hospedagens.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one., con...
# 4  [the, “studio, at, mibbett, hollow', is, in, a...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  [lower, queen, anne, is, near, the, seattle, c...                     1
# 1  [upper, queen, anne, is, a, really, pleasant,,...                     1
# 2  [the, convenience, of, being, in, seattle, but...                     1
# ...

# %%
dados_hospedagens['comodidades'] = dados_hospedagens['comodidades'].str.replace('[\{|}|\"]', "", regex=True).str.split(",")
dados_hospedagens.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one., con...
# 4  [the, “studio, at, mibbett, hollow', is, in, a...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  [lower, queen, anne, is, near, the, seattle, c...                     1
# 1  [upper, queen, anne, is, a, really, pleasant,,...                     1
# 2  [the, convenience, of, being, in, seattle, but...                     1
# ...

# %% [markdown]
# ## DATETIME
#
# Como nanipular e usar dados de datas

# %%
moveis_disponiveis
# Out:
#           id        data  vaga_disponivel    preco
# 0        857  2016-01-04            False     None
# 1        857  2016-01-05            False     None
# 2        857  2016-01-06            False     None
# 3        857  2016-01-07            False     None
# 4        857  2016-01-08            False     None
# ...      ...         ...              ...      ...
# 364995  3279  2016-12-29             True  $140.00
# 364996  3279  2016-12-30             True  $140.00
# 364997  3279  2016-12-31             True  $140.00
# 364998  3279  2017-01-01             True  $140.00
# 364999  3279  2017-01-02            False     None
#
# [365000 rows x 4 columns]

# %%
moveis_disponiveis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               365000 non-null  int64
#  1   data             365000 non-null  object
#  2   vaga_disponivel  365000 non-null  bool
#  3   preco            270547 non-null  object
# dtypes: bool(1), int64(1), object(2)
# memory usage: 11.5+ MB

# %%
moveis_disponiveis['data'] = pd.to_datetime(moveis_disponiveis['data'])

# %%
moveis_disponiveis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               365000 non-null  int64
#  1   data             365000 non-null  datetime64[ns]
#  2   vaga_disponivel  365000 non-null  bool
#  3   preco            270547 non-null  object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(1)
# memory usage: 11.5+ MB

# %%
moveis_disponiveis['data'].dt.strftime("%Y-%m")
# Out:
# 0         2016-01
# 1         2016-01
# 2         2016-01
# 3         2016-01
# 4         2016-01
#            ...
# 364995    2016-12
# 364996    2016-12
# 364997    2016-12
# 364998    2017-01
# 364999    2017-01
# Name: data, Length: 365000, dtype: object

# %%
subset = moveis_disponiveis.groupby(moveis_disponiveis['data'].dt.strftime("%Y-%m"))[['vaga_disponivel']].sum()
subset
# Out:
#          vaga_disponivel
# data
# 2016-01            16543
# 2016-02            20128
# 2016-03            23357
# 2016-04            22597
# 2016-05            23842
# 2016-06            23651
# 2016-07            22329
# 2016-08            22529
# 2016-09            22471
# 2016-10            23765
# 2016-11            23352
# 2016-12            24409
# 2017-01             1574

# %% [markdown]
# ## PROJETOS
#
# ### PROJETO 1 - VENDAS OLINE
#
# ### PROJETO 2 - ADMINISTRAÇÃO DE CONDOMINIOS
#
# para ambos os projetos deve ser aplicado o JSON normalize nos dados.

# %%
link_vendas_online = "https://caelum-online-public.s3.amazonaws.com/2928-transformacao-manipulacao-dados/dados_vendas_clientes.json"
link_adm_condominios  = "https://caelum-online-public.s3.amazonaws.com/2928-transformacao-manipulacao-dados/dados_locacao_imoveis.json"

# %%
data_vendas_online = pd.json_normalize(pd.read_json(link_vendas_online)["dados_vendas"])
data_vendas_online
# Out:
#   Data de venda                                            Cliente  \
# 0    06/06/2022  [@ANA _LUCIA 321, DieGO ARMANDIU 210, DieGO AR...
# 1    07/06/2022  [Isabely JOanes 738, Isabely JOanes 738, Isabe...
# 2    08/06/2022  [Isabely JOanes 738, JOãO Gabriel 671, Julya m...
# 3    09/06/2022  [Julya meireles 914, MaRIA Julia 444, MaRIA Ju...
# 4    10/06/2022  [MaRIA Julia 444, PEDRO PASCO 812, Paulo castr...
#
#                                 Valor da compra
# 0    [R$ 836,5, R$ 573,33, R$ 392,8, R$ 512,34]
# 1  [R$ 825,31, R$ 168,07, R$ 339,18, R$ 314,69]
# 2  [R$ 682,05, R$ 386,34, R$ 622,65, R$ 630,79]
# 3   [R$ 390,3, R$ 759,16, R$ 334,47, R$ 678,78]
# 4  [R$ 314,24, R$ 311,15, R$ 899,16, R$ 885,24]

# %%
data_adm_condominios = pd.json_normalize(pd.read_json(link_adm_condominios)["dados_locacao"])
data_adm_condominios.head()
# Out:
#       apartamento datas_combinadas_pagamento        datas_de_pagamento  \
# 0  A101 (blocoAP)   [01/06/2022, 01/07/2022]  [05/06/2022, 03/07/2022]
# 1  A102 (blocoAP)   [02/06/2022, 02/07/2022]  [02/06/2022, 06/07/2022]
# 2  B201 (blocoAP)   [03/06/2022, 03/07/2022]  [07/06/2022, 03/07/2022]
# 3  B202 (blocoAP)   [04/06/2022, 04/07/2022]  [07/06/2022, 05/07/2022]
# 4  C301 (blocoAP)   [05/06/2022, 05/07/2022]  [10/06/2022, 09/07/2022]
#
#                       valor_aluguel
# 0  [$ 1000,0 reais, $ 2500,0 reais]
# 1  [$ 1100,0 reais, $ 2600,0 reais]
# 2  [$ 1200,0 reais, $ 2700,0 reais]
# 3  [$ 1300,0 reais, $ 2800,0 reais]
# 4  [$ 1400,0 reais, $ 2900,0 reais]

# %% [markdown]
# ## Transforma dados em númericos
# ## Desagrupar os dados

# %%
cols_vendas = list(data_vendas_online.columns)
cols_vendas
# Out:
# ['Data de venda', 'Cliente', 'Valor da compra']

# %%
data_vendas_online = data_vendas_online.explode(cols_vendas[1:])
data_vendas_online
# Out:
#   Data de venda             Cliente Valor da compra
# 0    06/06/2022     @ANA _LUCIA 321        R$ 836,5
# 0    06/06/2022  DieGO ARMANDIU 210       R$ 573,33
# 0    06/06/2022  DieGO ARMANDIU 210        R$ 392,8
# 0    06/06/2022  DieGO ARMANDIU 210       R$ 512,34
# 1    07/06/2022  Isabely JOanes 738       R$ 825,31
# 1    07/06/2022  Isabely JOanes 738       R$ 168,07
# 1    07/06/2022  Isabely JOanes 738       R$ 339,18
# 1    07/06/2022  Isabely JOanes 738       R$ 314,69
# 2    08/06/2022  Isabely JOanes 738       R$ 682,05
# 2    08/06/2022    JOãO Gabriel 671       R$ 386,34
# 2    08/06/2022  Julya meireles 914       R$ 622,65
# 2    08/06/2022  Julya meireles 914       R$ 630,79
# 3    09/06/2022  Julya meireles 914        R$ 390,3
# 3    09/06/2022     MaRIA Julia 444       R$ 759,16
# 3    09/06/2022     MaRIA Julia 444       R$ 334,47
# 3    09/06/2022     MaRIA Julia 444       R$ 678,78
# 4    10/06/2022     MaRIA Julia 444       R$ 314,24
# ...

# %%
data_vendas_online['Valor da compra'] = data_vendas_online['Valor da compra'].apply(lambda x : x.replace("R$", "").replace(".", "").replace(",", ".").strip()).astype(np.float64)
data_vendas_online.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    20 non-null     object
#  1   Cliente          20 non-null     object
#  2   Valor da compra  20 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.2+ KB

# %%
cols_adm_condomino = list(data_adm_condominios.columns)
cols_adm_condomino
# Out:
# ['apartamento',
#  'datas_combinadas_pagamento',
#  'datas_de_pagamento',
#  'valor_aluguel']

# %%
data_adm_condominios = data_adm_condominios.explode(cols_adm_condomino[1:])
data_adm_condominios
# Out:
#        apartamento datas_combinadas_pagamento datas_de_pagamento  \
# 0   A101 (blocoAP)                 01/06/2022         05/06/2022
# 0   A101 (blocoAP)                 01/07/2022         03/07/2022
# 1   A102 (blocoAP)                 02/06/2022         02/06/2022
# 1   A102 (blocoAP)                 02/07/2022         06/07/2022
# 2   B201 (blocoAP)                 03/06/2022         07/06/2022
# 2   B201 (blocoAP)                 03/07/2022         03/07/2022
# 3   B202 (blocoAP)                 04/06/2022         07/06/2022
# 3   B202 (blocoAP)                 04/07/2022         05/07/2022
# 4   C301 (blocoAP)                 05/06/2022         10/06/2022
# 4   C301 (blocoAP)                 05/07/2022         09/07/2022
# 5   C302 (blocoAP)                 06/06/2022         08/06/2022
# 5   C302 (blocoAP)                 06/07/2022         12/07/2022
# 6   D401 (blocoAP)                 07/06/2022         07/06/2022
# ...

# %%
data_adm_condominios["valor_aluguel"] = data_adm_condominios["valor_aluguel"].apply(lambda x : x.replace('$', "").replace(",", ".").replace("reais", "").strip()).astype(np.float64)
data_adm_condominios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   apartamento                 30 non-null     object
#  1   datas_combinadas_pagamento  30 non-null     object
#  2   datas_de_pagamento          30 non-null     object
#  3   valor_aluguel               30 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 2.2+ KB

# %%
data_adm_condominios
# Out:
#        apartamento datas_combinadas_pagamento datas_de_pagamento  \
# 0   A101 (blocoAP)                 01/06/2022         05/06/2022
# 0   A101 (blocoAP)                 01/07/2022         03/07/2022
# 1   A102 (blocoAP)                 02/06/2022         02/06/2022
# 1   A102 (blocoAP)                 02/07/2022         06/07/2022
# 2   B201 (blocoAP)                 03/06/2022         07/06/2022
# 2   B201 (blocoAP)                 03/07/2022         03/07/2022
# 3   B202 (blocoAP)                 04/06/2022         07/06/2022
# 3   B202 (blocoAP)                 04/07/2022         05/07/2022
# 4   C301 (blocoAP)                 05/06/2022         10/06/2022
# 4   C301 (blocoAP)                 05/07/2022         09/07/2022
# 5   C302 (blocoAP)                 06/06/2022         08/06/2022
# 5   C302 (blocoAP)                 06/07/2022         12/07/2022
# 6   D401 (blocoAP)                 07/06/2022         07/06/2022
# ...

# %% [markdown]
# ## TRABALHANDO COM STRINGS

# %%
## TRABALHANDO COM STRINGS

data_vendas_online['Cliente'] = data_vendas_online['Cliente'].str.lower().str.replace("[^A-Za-z[ ]]", "", regex=True).str.replace("[\@\_0-9]", "", regex=True)
data_vendas_online.head()
# Out:
#   Data de venda          Cliente  Valor da compra
# 0    06/06/2022       ana lucia            836.50
# 0    06/06/2022  diego armandiu            573.33
# 0    06/06/2022  diego armandiu            392.80
# 0    06/06/2022  diego armandiu            512.34
# 1    07/06/2022  isabely joanes            825.31

# %%
data_vendas_online
# Out:
#   Data de venda          Cliente  Valor da compra
# 0    06/06/2022       ana lucia            836.50
# 0    06/06/2022  diego armandiu            573.33
# 0    06/06/2022  diego armandiu            392.80
# 0    06/06/2022  diego armandiu            512.34
# 1    07/06/2022  isabely joanes            825.31
# 1    07/06/2022  isabely joanes            168.07
# 1    07/06/2022  isabely joanes            339.18
# 1    07/06/2022  isabely joanes            314.69
# 2    08/06/2022  isabely joanes            682.05
# 2    08/06/2022    joão gabriel            386.34
# 2    08/06/2022  julya meireles            622.65
# 2    08/06/2022  julya meireles            630.79
# 3    09/06/2022  julya meireles            390.30
# 3    09/06/2022     maria julia            759.16
# 3    09/06/2022     maria julia            334.47
# 3    09/06/2022     maria julia            678.78
# 4    10/06/2022     maria julia            314.24
# 4    10/06/2022     pedro pasco            311.15
# ...

# %%
data_adm_condominios['apartamento'] = data_adm_condominios['apartamento'].str.replace('(\b|\()blocoAP(\b|\))', '', regex=True)

# %%
data_adm_condominios
# Out:
#    apartamento datas_combinadas_pagamento datas_de_pagamento  valor_aluguel
# 0        A101                  01/06/2022         05/06/2022         1000.0
# 0        A101                  01/07/2022         03/07/2022         2500.0
# 1        A102                  02/06/2022         02/06/2022         1100.0
# 1        A102                  02/07/2022         06/07/2022         2600.0
# 2        B201                  03/06/2022         07/06/2022         1200.0
# 2        B201                  03/07/2022         03/07/2022         2700.0
# 3        B202                  04/06/2022         07/06/2022         1300.0
# 3        B202                  04/07/2022         05/07/2022         2800.0
# 4        C301                  05/06/2022         10/06/2022         1400.0
# 4        C301                  05/07/2022         09/07/2022         2900.0
# 5        C302                  06/06/2022         08/06/2022         1500.0
# ...
